# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
% matplotlib inline
import seaborn as sns

# %%
n2l = np.load('../data/map.npy')[()]['n2l']

# %%
pred_nnsoft_val=np.load('../pred_nnsoft_val.npy')
pred_svm_val=np.load('../pred_svm_val.npy')
pred_nnsig_val=np.load('../pred_nnsig_val.npy')

pred_nnsoft_test=np.load('../pred_nnsoft_test.npy')
pred_svm_test=np.load('../pred_svm_test.npy')
pred_nnsig_test=np.load('../pred_nnsig_test.npy')

# %%
pred_nnsoft_val
# Out:
# array([15, 15, 15, ..., 44, 44, 44])

# %%
pred_nnsig_val
# Out:
# array([15, 15, 15, ..., 44, 44, 44])

# %%
pred_svm_val
# Out:
# array([15, 15, 15, ..., 44, 44, 44])

# %%
pred_svm_test = pd.DataFrame(pred_svm_test)
pred_nnsoft_test = pd.DataFrame(pred_nnsoft_test)
pred_nnsig_test = pd.DataFrame(pred_nnsig_test)

# %%
subm_all = pd.concat([pred_svm_test, pred_nnsoft_test,pred_nnsig_test],1)

# %%
subm_all
# Out:
#        0   0   0
# 0     36  36  36
# 1      3  23  23
# 2     36  36  36
# 3     32  32  32
# 4     32  24  32
# 5     11  41  41
# 6     26  42  26
# 7     18  18  18
# 8     43  45   4
# 9     26  21  43
# 10    42  42  43
# 11    31  14  14
# 12    26  21  26
# 13     5  12  12
# 14    26  42  43
# 15    42  42  43
# 16    26  23  26
# 17    30  30  30
# 18    26  42  43
# 19    36  36  36
# 20     5  12   5
# 21    26  42  26
# 22    23  23  23
# 23    26  23  26
# 24    37   8  37
# 25    36  36  36
# 26    36  36  36
# 27     8   8  37
# 28    26  21  43
# 29    26  23  26
# ...   ..  ..  ..
# 2825  26  21  26
# 2826  29  29  29
# 2827  26  35  26
# 2828  26  21  26
# 2829   5  19  16
# 2830  26  21  26
# 2831  11  29  29
# 2832  36  36  36
# 2833   3  23  26
# 2834  42  23  43
# 2835  26  42  26
# 2836   5  12  12
# 2837   5  12  12
# 2838  41  41  41
# 2839   8  37  37
# 2840  42  42  26
# 2841  32   8   8
# 2842  26  42  26
# 2843  26  42  26
# 2844  26  21  26
# 2845  26  42  43
# 2846  26   3  26
# 2847   0   0  23
# 2848  29  29  29
# 2849  32  32  32
# 2850  26  42  43
# 2851  24  21  39
# 2852  23  23  23
# 2853  12  12  12
# 2854  23  23  23
#
# [2855 rows x 3 columns]

# %%
from scipy.stats import mode

# %%
# vote
test = []
for i in range(len(pred_nnsig_test)):
    #print [pred_nnsoft_val[i],pred_nnsig_val[i],pred_svm_val[i]]
    a,b = mode([pred_nnsoft_test[i],pred_nnsig_test[i],pred_svm_test[i]])
    if b[0] == 1:
        test.append(pred_nnsig_test[i])
    else:
        test.append(a[0])

# %%
sum(np.asarray(ls) == val)/float(len(ls))
# Out:
# 0.5702283498492029

# %%
subm_all.mode(axis=1)
# Out:
#          0     1
# 0     15.0   NaN
# 1     15.0   NaN
# 2     15.0   NaN
# 3     15.0   NaN
# 4     15.0   NaN
# 5     15.0   NaN
# 6     15.0   NaN
# 7     15.0   NaN
# 8     15.0   NaN
# 9     15.0   NaN
# 10    15.0   NaN
# 11    15.0   NaN
# 12    15.0   NaN
# 13    15.0   NaN
# 14    15.0   NaN
# 15    15.0   NaN
# 16    37.0   NaN
# 17    37.0   NaN
# 18    37.0   NaN
# 19    37.0   NaN
# 20    37.0   NaN
# 21    37.0   NaN
# 22    37.0   NaN
# 23    37.0   NaN
# 24    37.0   NaN
# 25    37.0   NaN
# 26    37.0   NaN
# 27    37.0   NaN
# 28    37.0   NaN
# 29    37.0   NaN
# ...    ...   ...
# 4612  39.0  42.0
# 4613  37.0  44.0
# 4614  37.0  44.0
# 4615  37.0  44.0
# 4616  37.0  44.0
# 4617  37.0  44.0
# 4618  37.0  44.0
# 4619  37.0  44.0
# 4620  37.0  44.0
# 4621  37.0  44.0
# 4622  37.0  44.0
# 4623  37.0  44.0
# 4624  44.0   NaN
# 4625  37.0  44.0
# 4626  37.0  44.0
# 4627  44.0   NaN
# 4628  44.0   NaN
# 4629  37.0  44.0
# 4630  37.0  44.0
# 4631  37.0  44.0
# 4632  37.0  44.0
# 4633  44.0   NaN
# 4634  44.0   NaN
# 4635  44.0   NaN
# 4636  44.0   NaN
# 4637  44.0   NaN
# 4638  44.0   NaN
# 4639  44.0   NaN
# 4640  44.0   NaN
# 4641  44.0   NaN
#
# [4642 rows x 2 columns]

# %%
val = pred_nnsoft_val

# %%
float(sum(ls == val))/len(ls)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-95f93ce04b27> in <module>()
# ----> 1 float(sum(ls == val))/len(ls)
#
# TypeError: 'bool' object is not iterable

# %%
n2l
# Out:
# {0: 'CL:0000353 blastoderm cell',
#  1: 'UBERON:0002107 liver',
#  2: 'CL:0000057 fibroblast',
#  3: 'CL:0002322 embryonic stem cell',
#  4: 'CL:0000081 blood cell',
#  5: 'UBERON:0000115 lung epithelium',
#  6: 'CL:0001056 dendritic cell, human',
#  7: 'CL:0000746 cardiac muscle cell',
#  8: 'UBERON:0001851 cortex',
#  9: 'CL:0002034 long term hematopoietic stem cell',
#  10: 'CL:0002033 short term hematopoietic stem cell',
#  11: 'CL:0000037 hematopoietic stem cell',
#  12: 'CL:1000497 kidney cell',
#  13: 'CL:0008019 mesenchymal cell',
#  14: 'UBERON:0000044 dorsal root ganglion',
#  15: 'CL:0002365 medullary thymic epithelial cell',
#  16: 'UBERON:0000473 testis',
#  17: 'UBERON:0000992 female gonad',
#  18: 'UBERON:0000922 embryo',
#  19: 'UBERON:0002048 lung',
#  20: 'CL:0000137 osteocyte',
#  21: 'UBERON:0001898 hypothalamus',
#  22: 'UBERON:0001997 olfactory epithelium',
#  23: 'CL:0002321 embryonic cell',
#  24: 'CL:0002319 neural cell',
#  25: 'UBERON:0004129 growth plate cartilage',
#  26: 'UBERON:0001891 midbrain',
#  27: 'UBERON:0002038 substantia nigra',
#  28: 'UBERON:0000007 pituitary gland',
#  29: 'CL:0000763 myeloid cell',
#  30: 'CL:0000540 neuron',
#  31: 'UBERON:0000045 ganglion',
#  32: "UBERON:0001954 Ammon's horn",
#  33: 'CL:0000127 astrocyte',
#  34: 'CL:0000163 endocrine cell',
#  35: 'UBERON:0000955 brain',
#  36: 'UBERON:0000966 retina',
#  37: 'UBERON:0002435 striatum',
#  38: 'UBERON:0010743 meningeal cluster',
#  39: 'CL:0000169 type B pancreatic cell',
#  40: 'UBERON:0001264 pancreas',
#  41: 'CL:0000084 T cell',
#  42: 'UBERON:0001003 skin epidermis',
#  43: 'UBERON:0001902 epithelium of small intestine',
#  44: 'CL:0000235 macrophage',
#  45: 'CL:0000192 smooth muscle cell'}

# %%
test[-10:]
# Out:
# [43, 26, 0, 29, 32, 43, 39, 23, 12, 23]

# %%
d = {'Cell Type': [n2l[i] for i in test]}
TEST_LAB_DF = pd.DataFrame(data=d)

# %%
TEST_LAB_DF
# Out:
#                                          Cell Type
# 0                            UBERON:0000966 retina
# 1                        CL:0002321 embryonic cell
# 2                            UBERON:0000966 retina
# 3                      UBERON:0001954 Ammon's horn
# 4                      UBERON:0001954 Ammon's horn
# 5                                CL:0000084 T cell
# 6                          UBERON:0001891 midbrain
# 7                            UBERON:0000922 embryo
# 8                            CL:0000081 blood cell
# 9     UBERON:0001902 epithelium of small intestine
# 10                   UBERON:0001003 skin epidermis
# 11             UBERON:0000044 dorsal root ganglion
# 12                         UBERON:0001891 midbrain
# 13                          CL:1000497 kidney cell
# 14    UBERON:0001902 epithelium of small intestine
# 15                   UBERON:0001003 skin epidermis
# 16                         UBERON:0001891 midbrain
# 17                               CL:0000540 neuron
# 18    UBERON:0001902 epithelium of small intestine
# 19                           UBERON:0000966 retina
# 20                  UBERON:0000115 lung epithelium
# 21                         UBERON:0001891 midbrain
# 22                       CL:0002321 embryonic cell
# 23                         UBERON:0001891 midbrain
# 24                         UBERON:0002435 striatum
# 25                           UBERON:0000966 retina
# 26                           UBERON:0000966 retina
# 27                           UBERON:0001851 cortex
# 28    UBERON:0001902 epithelium of small intestine
# 29                         UBERON:0001891 midbrain
# ...                                            ...
# 2825                       UBERON:0001891 midbrain
# 2826                       CL:0000763 myeloid cell
# 2827                       UBERON:0001891 midbrain
# 2828                       UBERON:0001891 midbrain
# 2829                         UBERON:0000473 testis
# 2830                       UBERON:0001891 midbrain
# 2831                       CL:0000763 myeloid cell
# 2832                         UBERON:0000966 retina
# 2833                       UBERON:0001891 midbrain
# 2834  UBERON:0001902 epithelium of small intestine
# 2835                       UBERON:0001891 midbrain
# 2836                        CL:1000497 kidney cell
# 2837                        CL:1000497 kidney cell
# 2838                             CL:0000084 T cell
# 2839                       UBERON:0002435 striatum
# 2840                 UBERON:0001003 skin epidermis
# 2841                         UBERON:0001851 cortex
# 2842                       UBERON:0001891 midbrain
# 2843                       UBERON:0001891 midbrain
# 2844                       UBERON:0001891 midbrain
# 2845  UBERON:0001902 epithelium of small intestine
# 2846                       UBERON:0001891 midbrain
# 2847                    CL:0000353 blastoderm cell
# 2848                       CL:0000763 myeloid cell
# 2849                   UBERON:0001954 Ammon's horn
# 2850  UBERON:0001902 epithelium of small intestine
# 2851             CL:0000169 type B pancreatic cell
# 2852                     CL:0002321 embryonic cell
# 2853                        CL:1000497 kidney cell
# 2854                     CL:0002321 embryonic cell
#
# [2855 rows x 1 columns]

# %%
TEST_LAB_DF.to_csv(path_or_buf='./test_predicted_labels.tsv',sep='\t',index=False)

# %%
pd.read_csv( './test_predicted_labels.tsv', sep='\t')
# Out:
#                                         Cell Type
# 0     CL:0002365 medullary thymic epithelial cell
# 1     CL:0002365 medullary thymic epithelial cell
# 2     CL:0002365 medullary thymic epithelial cell
# 3     CL:0002365 medullary thymic epithelial cell
# 4     CL:0002365 medullary thymic epithelial cell
# 5     CL:0002365 medullary thymic epithelial cell
# 6     CL:0002365 medullary thymic epithelial cell
# 7     CL:0002365 medullary thymic epithelial cell
# 8     CL:0002365 medullary thymic epithelial cell
# 9     CL:0002365 medullary thymic epithelial cell
# 10    CL:0002365 medullary thymic epithelial cell
# 11    CL:0002365 medullary thymic epithelial cell
# 12    CL:0002365 medullary thymic epithelial cell
# 13    CL:0002365 medullary thymic epithelial cell
# 14    CL:0002365 medullary thymic epithelial cell
# 15    CL:0002365 medullary thymic epithelial cell
# 16                        UBERON:0002435 striatum
# 17                        UBERON:0002435 striatum
# 18                        UBERON:0002435 striatum
# 19                        UBERON:0002435 striatum
# 20                        UBERON:0002435 striatum
# 21                        UBERON:0002435 striatum
# 22                        UBERON:0002435 striatum
# 23                        UBERON:0002435 striatum
# 24                        UBERON:0002435 striatum
# 25                        UBERON:0002435 striatum
# 26                        UBERON:0002435 striatum
# 27                        UBERON:0002435 striatum
# 28                        UBERON:0002435 striatum
# 29                        UBERON:0002435 striatum
# ...                                           ...
# 2825                        UBERON:0000473 testis
# 2826                    CL:0002321 embryonic cell
# 2827                    CL:0002321 embryonic cell
# 2828                    CL:0002321 embryonic cell
# 2829                        UBERON:0000473 testis
# 2830                        UBERON:0000473 testis
# 2831                        UBERON:0000473 testis
# 2832                    CL:0002321 embryonic cell
# 2833                        UBERON:0000473 testis
# 2834                        UBERON:0000473 testis
# 2835                        UBERON:0000473 testis
# 2836                        UBERON:0000473 testis
# 2837                        UBERON:0000473 testis
# 2838                        UBERON:0000473 testis
# 2839                        UBERON:0000473 testis
# 2840                        UBERON:0000473 testis
# 2841                        UBERON:0000473 testis
# 2842                        UBERON:0000473 testis
# 2843                        UBERON:0000473 testis
# 2844                        UBERON:0000473 testis
# 2845                        UBERON:0000473 testis
# 2846                        UBERON:0000473 testis
# 2847                        UBERON:0000473 testis
# 2848                        UBERON:0000473 testis
# 2849                        UBERON:0000473 testis
# 2850                        UBERON:0000473 testis
# 2851                        UBERON:0000473 testis
# 2852                        UBERON:0000473 testis
# 2853                    CL:0002321 embryonic cell
# 2854                        UBERON:0000473 testis
#
# [2855 rows x 1 columns]

# %%
plt.figure(figsize=(10,10))
sns.countplot(y=pred)

# %%
# read tf record
ls = []
tfrecords_filename = '../data/val.tfrecords'
record_iterator = tf.python_io.tf_record_iterator(path=tfrecords_filename.format(0))
for i,string_record in enumerate(record_iterator):
    example = tf.train.Example()
    example.ParseFromString(string_record)
    img_string = (example.features.feature)
    ls.append( img_string['label'].int64_list.value[0] )
    #print i
    #print ls[-1]
    # print np.sum(img_string['data'].float_list.value)
    #if i==100:
    #    break
